# %%
using Colors
include("equilibration.jl")
grid,steps = Equilibration(50,1.0,1.0)
print(steps)
Gray.(grid)
# Out:
# 1900000
# 50×50 Array{ColorTypes.Gray{Float64},2}:
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  ⋮                                         ⋱
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)  …  Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)  …  Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)

# %%
dir=Dates.format(now(), "yyyy-mm-dd HH:MM:SS")

include("equilibration.jl")
include("production.jl")
using Gadfly

n_grid=35
T=1.5
J=1.0
L=1000000

grid,steps=Equilibration(n_grid,T,J)
correlation = Array{Float64}(11,size(1:convert(Int64,ceil(n_grid/2))-1)[1])
for r in 1:convert(Int64,ceil(n_grid/2))-1
    gridpr,corr=Production(n_grid,T,J,L,grid,r)
    correlation[:,r]=corr
end
correlation=transpose(correlation)
# plot(x=convert(Array,1:convert(Int64,ceil(n_grid/2))-2),y=correlation[:,5],Geom.point,Geom.line)

mkpath("Data/$n_grid/$dir")
fid=open("Data/$n_grid/$dir/r_corrfunc.dat","w")
writecsv(fid, correlation)
close(fid)

fid=open("Data/$n_grid/$dir/sys_details.dat","w")
@printf(fid,"%s %s\r\n","Date/Time : ",Dates.format(now(), "yyyy-mm-dd HH:MM:SS"));
@printf(fid,"%s %f\r\n","J=",J);
@printf(fid,"%s %u\r\n","Lattice Size=",n_grid);
@printf(fid,"%s %f\r\n","temperature = ",T);
# @printf(fid,"%s %f\r\n","Maximum temperature = ",Tmax);
# @printf(fid,"%s %f\r\n","Increment in temperature = ",Tinc);
# @printf(fid,"%s %u\r\n","No.of Production run = ",P);
@printf(fid,"%s %u\r\n","No.of steps in production run = ",L);
# @printf(fid,"%s\r\n","Data:");
# @printf(fid,"%6s %12s %14s\r\n\r\n","r (distance)","Correlation function","Error");
close(fid)
# Out:
# Finished

# %%
(correlation)
# Out:
# 17×11 Array{Float64,2}:
#  -Inf               0.0328554    …    -1.55193e86    0.00376375
#    -0.00288143      0.0012967       -Inf             0.0087525
#     0.00922508      1.22491e212     -Inf             0.00179281
#     0.0174523    -Inf               -Inf            -0.00841301
#     0.00915246   -Inf               -Inf             0.0497563
#     3.12841e174  -Inf            …  -Inf             0.137556
#     0.00981635      0.00838152      -Inf             0.0592895
#  -Inf              -0.0105356          5.71084e222   0.215637
#     0.011518       -9.34765e-5      -Inf             0.209292
#  -Inf               0.000624487       -1.24576e49    0.0451152
#  -Inf              -0.0258176    …    -1.24576e49   -0.0477293
#  -Inf               0.0117119         -1.24576e49    0.0135273
#  -Inf               0.00957655         5.71084e222  -0.0247677
#  -Inf               0.00270152        -1.24576e49    0.0130353
#     4.67661e246     0.0110154       -Inf            -0.0535687
#  -Inf              -0.22061      …    -1.24576e49   -0.00370754
#  -Inf               0.00647201        -1.24576e49   -0.0156706

# %%
using Colors
Gray.(grid)
# Out:
# 35×35 Array{ColorTypes.Gray{Float64},2}:
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)   …  Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(1.0)      Gray{Float64}(1.0)
#  ⋮                                         ⋱
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)  …  Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(1.0)   Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)  …  Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
#  Gray{Float64}(-1.0)  Gray{Float64}(-1.0)     Gray{Float64}(-1.0)
